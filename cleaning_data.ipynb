# %% [markdown]
# # Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train = pd.read_csv("genome_train.csv")
test = pd.read_csv("genome_test.csv")

# %%
train.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 22083 entries, 0 to 22082
# Data columns (total 45 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Patient Id                                        22083 non-null  str
#  1   Patient Age                                       20656 non-null  float64
#  2   Genes in mother's side                            22083 non-null  str
#  3   Inherited from father                             21777 non-null  str
#  4   Maternal gene                                     19273 non-null  str
#  5   Paternal gene                                     22083 non-null  str
#  6   Blood cell count (mcL)                            22083 non-null  float64
#  7   Patient First Name                                22083 non-null  str
#  8   Family Name                                       12392 non-null  str
#  9   Father's name                                     22083 non-null  str
#  10  Mother's age                                      16047 non-null  float64
#  11  Father's age                                      16097 non-null  float64
#  12  Institute Name                                    16977 non-null  str
#  13  Location of Institute                             22083 non-null  str
#  14  Status                                            22083 non-null  str
#  15  Respiratory Rate (breaths/min)                    19934 non-null  str
#  16  Heart Rate (rates/min                             19970 non-null  str
#  17  Test 1                                            19956 non-null  float64
#  18  Test 2                                            19931 non-null  float64
#  19  Test 3                                            19936 non-null  float64
#  20  Test 4                                            19943 non-null  float64
#  21  Test 5                                            19913 non-null  float64
#  22  Parental consent                                  19958 non-null  str
#  23  Follow-up                                         19917 non-null  str
#  24  Gender                                            19910 non-null  str
#  25  Birth asphyxia                                    19944 non-null  str
#  26  Autopsy shows birth defect (if applicable)        17691 non-null  str
#  27  Place of birth                                    19959 non-null  str
#  28  Folic acid details (peri-conceptional)            19966 non-null  str
#  29  H/O serious maternal illness                      19931 non-null  str
#  30  H/O radiation exposure (x-ray)                    19930 non-null  str
#  31  H/O substance abuse                               19888 non-null  str
#  32  Assisted conception IVF/ART                       19961 non-null  str
#  33  History of anomalies in previous pregnancies      19911 non-null  str
#  34  No. of previous abortion                          19921 non-null  float64
#  35  Birth defects                                     19929 non-null  str
#  36  White Blood cell count (thousand per microliter)  19935 non-null  float64
#  37  Blood test result                                 19938 non-null  str
#  38  Symptom 1                                         19928 non-null  float64
#  39  Symptom 2                                         19861 non-null  float64
#  40  Symptom 3                                         19982 non-null  float64
#  41  Symptom 4                                         19970 non-null  float64
#  42  Symptom 5                                         19930 non-null  float64
#  43  Genetic Disorder                                  19937 non-null  str
#  44  Disorder Subclass                                 19915 non-null  str
# dtypes: float64(16), str(29)
# memory usage: 7.6 MB

# %%
test.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9465 entries, 0 to 9464
# Data columns (total 43 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Patient Id                                        9465 non-null   str
#  1   Patient Age                                       9465 non-null   int64
#  2   Genes in mother's side                            9465 non-null   str
#  3   Inherited from father                             8914 non-null   str
#  4   Maternal gene                                     5742 non-null   str
#  5   Paternal gene                                     9465 non-null   str
#  6   Blood cell count (mcL)                            9465 non-null   float64
#  7   Patient First Name                                9465 non-null   str
#  8   Family Name                                       148 non-null    str
#  9   Father's name                                     9465 non-null   str
#  10  Mother's age                                      9465 non-null   int64
#  11  Father's age                                      9465 non-null   int64
#  12  Institute Name                                    7429 non-null   str
#  13  Location of Institute                             9465 non-null   str
#  14  Status                                            9465 non-null   str
#  15  Respiratory Rate (breaths/min)                    6579 non-null   str
#  16  Heart Rate (rates/min                             6565 non-null   str
#  17  Test 1                                            9465 non-null   int64
#  18  Test 2                                            9465 non-null   int64
#  19  Test 3                                            9465 non-null   int64
#  20  Test 4                                            9465 non-null   int64
#  21  Test 5                                            9465 non-null   int64
#  22  Parental consent                                  9465 non-null   str
#  23  Follow-up                                         9465 non-null   str
#  24  Gender                                            9465 non-null   str
#  25  Birth asphyxia                                    9465 non-null   str
#  26  Autopsy shows birth defect (if applicable)        8265 non-null   str
#  27  Place of birth                                    9465 non-null   str
#  28  Folic acid details (peri-conceptional)            9465 non-null   str
#  29  H/O serious maternal illness                      9465 non-null   str
#  30  H/O radiation exposure (x-ray)                    9465 non-null   str
#  31  H/O substance abuse                               9465 non-null   str
#  32  Assisted conception IVF/ART                       9465 non-null   str
#  33  History of anomalies in previous pregnancies      9465 non-null   str
#  34  No. of previous abortion                          9465 non-null   int64
#  35  Birth defects                                     9465 non-null   str
#  36  White Blood cell count (thousand per microliter)  9465 non-null   float64
#  37  Blood test result                                 9465 non-null   str
#  38  Symptom 1                                         9465 non-null   bool
#  39  Symptom 2                                         9465 non-null   bool
#  40  Symptom 3                                         9465 non-null   bool
#  41  Symptom 4                                         9465 non-null   bool
#  42  Symptom 5                                         9465 non-null   bool
# dtypes: bool(5), float64(2), int64(9), str(27)
# memory usage: 2.8 MB

# %%
train.isnull().sum()
# Out:
# Patient Id                                             0
# Patient Age                                         1427
# Genes in mother's side                                 0
# Inherited from father                                306
# Maternal gene                                       2810
# Paternal gene                                          0
# Blood cell count (mcL)                                 0
# Patient First Name                                     0
# Family Name                                         9691
# Father's name                                          0
# Mother's age                                        6036
# Father's age                                        5986
# Institute Name                                      5106
# Location of Institute                                  0
# Status                                                 0
# Respiratory Rate (breaths/min)                      2149
# Heart Rate (rates/min                               2113
# Test 1                                              2127
# Test 2                                              2152
# Test 3                                              2147
# Test 4                                              2140
# Test 5                                              2170
# Parental consent                                    2125
# Follow-up                                           2166
# Gender                                              2173
# Birth asphyxia                                      2139
# Autopsy shows birth defect (if applicable)          4392
# Place of birth                                      2124
# Folic acid details (peri-conceptional)              2117
# H/O serious maternal illness                        2152
# H/O radiation exposure (x-ray)                      2153
# H/O substance abuse                                 2195
# Assisted conception IVF/ART                         2122
# History of anomalies in previous pregnancies        2172
# No. of previous abortion                            2162
# Birth defects                                       2154
# White Blood cell count (thousand per microliter)    2148
# Blood test result                                   2145
# Symptom 1                                           2155
# Symptom 2                                           2222
# Symptom 3                                           2101
# Symptom 4                                           2113
# Symptom 5                                           2153
# Genetic Disorder                                    2146
# Disorder Subclass                                   2168
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Patient Id                                             0
# Patient Age                                            0
# Genes in mother's side                                 0
# Inherited from father                                551
# Maternal gene                                       3723
# Paternal gene                                          0
# Blood cell count (mcL)                                 0
# Patient First Name                                     0
# Family Name                                         9317
# Father's name                                          0
# Mother's age                                           0
# Father's age                                           0
# Institute Name                                      2036
# Location of Institute                                  0
# Status                                                 0
# Respiratory Rate (breaths/min)                      2886
# Heart Rate (rates/min                               2900
# Test 1                                                 0
# Test 2                                                 0
# Test 3                                                 0
# Test 4                                                 0
# Test 5                                                 0
# Parental consent                                       0
# Follow-up                                              0
# Gender                                                 0
# Birth asphyxia                                         0
# Autopsy shows birth defect (if applicable)          1200
# Place of birth                                         0
# Folic acid details (peri-conceptional)                 0
# H/O serious maternal illness                           0
# H/O radiation exposure (x-ray)                         0
# H/O substance abuse                                    0
# Assisted conception IVF/ART                            0
# History of anomalies in previous pregnancies           0
# No. of previous abortion                               0
# Birth defects                                          0
# White Blood cell count (thousand per microliter)       0
# Blood test result                                      0
# Symptom 1                                              0
# Symptom 2                                              0
# Symptom 3                                              0
# Symptom 4                                              0
# Symptom 5                                              0
# dtype: int64

# %%
(test == "-99").sum()
# Out:
# Patient Id                                             0
# Patient Age                                            0
# Genes in mother's side                                 0
# Inherited from father                                  0
# Maternal gene                                          0
# Paternal gene                                          0
# Blood cell count (mcL)                                 0
# Patient First Name                                     0
# Family Name                                            0
# Father's name                                          0
# Mother's age                                           0
# Father's age                                           0
# Institute Name                                      2968
# Location of Institute                                  0
# Status                                                 0
# Respiratory Rate (breaths/min)                      2105
# Heart Rate (rates/min                               2074
# Test 1                                                 0
# Test 2                                                 0
# Test 3                                                 0
# Test 4                                                 0
# Test 5                                                 0
# Parental consent                                    2095
# Follow-up                                           2090
# Gender                                              2102
# Birth asphyxia                                      2079
# Autopsy shows birth defect (if applicable)          1063
# Place of birth                                      2089
# Folic acid details (peri-conceptional)              2092
# H/O serious maternal illness                        2080
# H/O radiation exposure (x-ray)                      2082
# H/O substance abuse                                 2095
# Assisted conception IVF/ART                         2085
# History of anomalies in previous pregnancies        2097
# No. of previous abortion                               0
# Birth defects                                       2095
# White Blood cell count (thousand per microliter)       0
# Blood test result                                   2080
# Symptom 1                                              0
# Symptom 2                                              0
# Symptom 3                                              0
# Symptom 4                                              0
# Symptom 5                                              0
# dtype: int64

# %%
test.replace("-99", np.nan, inplace=True)
# Out:
#      Patient Id  Patient Age Genes in mother's side Inherited from father  \
# 0     PID0x4175            6                     No                   Yes
# 1     PID0x21f5           10                    Yes                    No
# 2     PID0x49b8            5                     No                   NaN
# 3     PID0x2d97           13                     No                   Yes
# 4     PID0x58da            5                     No                   NaN
# ...         ...          ...                    ...                   ...
# 9460  PID0x81e1            9                    Yes                   Yes
# 9461  PID0x3514            1                    Yes                    No
# 9462  PID0x5408            2                     No                   Yes
# 9463  PID0x2017           13                     No                   Yes
# 9464  PID0x7f61           12                     No                    No
#
#      Maternal gene Paternal gene  Blood cell count (mcL) Patient First Name  \
# 0               No            No                4.981655            Charles
# 1              NaN           Yes                5.118890          Catherine
# 2               No            No                4.876204              James
# 3              Yes            No                4.687767              Brian
# 4              NaN           Yes                5.152362               Gary
# ...            ...           ...                     ...                ...
# 9460           NaN            No                4.878335          Francisco
# 9461           NaN           Yes                4.927151              James
# 9462            No            No                4.898352            Rebecca
# 9463            No            No                4.804840              Daryl
# 9464           Yes           Yes                5.421236            Leonard
#
#      Family Name Father's name  ...  \
# 0            NaN          Kore  ...
# 1            NaN        Homero  ...
# 2            NaN       Danield  ...
# 3            NaN       Orville  ...
# 4            NaN        Issiah  ...
# ...          ...           ...  ...
# 9460         NaN      Artavian  ...
# 9461         NaN         Nasir  ...
# 9462         NaN      Jatorian  ...
# 9463         NaN        Keevis  ...
# 9464         NaN      Jazarion  ...
#
#       History of anomalies in previous pregnancies  No. of previous abortion  \
# 0                                              NaN                         2
# 1                                              Yes                       -99
# 2                                               No                         0
# 3                                              Yes                       -99
# 4                                               No                       -99
# ...                                            ...                       ...
# 9460                                           Yes                         2
# 9461                                            No                       -99
# 9462                                            No                         3
# 9463                                           NaN                         1
# 9464                                            No                         0
#
#      Birth defects White Blood cell count (thousand per microliter)  \
# 0         Multiple                                       -99.000000
# 1         Multiple                                         8.179584
# 2         Singular                                       -99.000000
# 3         Singular                                         6.884071
# 4         Multiple                                         6.195178
# ...            ...                                              ...
# 9460      Multiple                                         7.234960
# 9461      Singular                                         4.859536
# 9462           NaN                                         5.696062
# 9463      Singular                                         3.000000
# 9464      Singular                                         7.492765
#
#       Blood test result Symptom 1 Symptom 2  Symptom 3  Symptom 4  Symptom 5
# 0     slightly abnormal      True      True       True       True       True
# 1                normal     False     False      False       True      False
# 2     slightly abnormal     False     False       True       True      False
# 3                normal      True     False       True      False       True
# 4                normal      True      True       True       True      False
# ...                 ...       ...       ...        ...        ...        ...
# 9460           abnormal     False      True       True       True      False
# 9461           abnormal     False      True      False       True       True
# 9462             normal     False      True      False      False       True
# 9463       inconclusive      True      True       True       True       True
# 9464           abnormal      True      True       True       True       True
#
# [9465 rows x 43 columns]

# %%
train.drop(columns=["Patient Id", "Institute Name", "Family Name"], inplace=True)
test.drop(columns=["Patient Id", "Institute Name", "Family Name"], inplace=True)

# %%
train.columns
# Out:
# Index(['Patient Age', 'Genes in mother's side', 'Inherited from father',
#        'Maternal gene', 'Paternal gene', 'Blood cell count (mcL)',
#        'Patient First Name', 'Father's name', 'Mother's age', 'Father's age',
#        'Location of Institute', 'Status', 'Respiratory Rate (breaths/min)',
#        'Heart Rate (rates/min', 'Test 1', 'Test 2', 'Test 3', 'Test 4',
#        'Test 5', 'Parental consent', 'Follow-up', 'Gender', 'Birth asphyxia',
#        'Autopsy shows birth defect (if applicable)', 'Place of birth',
#        'Folic acid details (peri-conceptional)',
#        'H/O serious maternal illness', 'H/O radiation exposure (x-ray)',
#        'H/O substance abuse', 'Assisted conception IVF/ART',
#        'History of anomalies in previous pregnancies',
#        'No. of previous abortion', 'Birth defects',
#        'White Blood cell count (thousand per microliter)', 'Blood test result',
#        'Symptom 1', 'Symptom 2', 'Symptom 3', 'Symptom 4', 'Symptom 5',
#        'Genetic Disorder', 'Disorder Subclass'],
#       dtype='str')

# %%
num_cols = train.select_dtypes(include=["int64", "float64"]).columns

# %%
for col in num_cols:
    print(col)
# Out:
# Patient Age
# Blood cell count (mcL)
# Mother's age
# Father's age
# Test 1
# Test 2
# Test 3
# Test 4
# Test 5
# No. of previous abortion
# White Blood cell count (thousand per microliter)
# Symptom 1
# Symptom 2
# Symptom 3
# Symptom 4
# Symptom 5

# %%
train[num_cols] = train[num_cols].fillna(train[num_cols].median())
test[num_cols] = test[num_cols].fillna(train[num_cols].median())

# %%
train.isnull().sum().sum()
# Out:
# np.int64(44021)

# %%
test.isnull().sum().sum()
# Out:
# np.int64(43663)

# %%
cat_cols = train.select_dtypes(include='str').columns

# %%
print(cat_cols)
# Out:
# Index(['Genes in mother's side', 'Inherited from father', 'Maternal gene',
#        'Paternal gene', 'Patient First Name', 'Father's name',
#        'Location of Institute', 'Status', 'Respiratory Rate (breaths/min)',
#        'Heart Rate (rates/min', 'Parental consent', 'Follow-up', 'Gender',
#        'Birth asphyxia', 'Autopsy shows birth defect (if applicable)',
#        'Place of birth', 'Folic acid details (peri-conceptional)',
#        'H/O serious maternal illness', 'H/O radiation exposure (x-ray)',
#        'H/O substance abuse', 'Assisted conception IVF/ART',
#        'History of anomalies in previous pregnancies', 'Birth defects',
#        'Blood test result', 'Genetic Disorder', 'Disorder Subclass'],
#       dtype='str')

# %%
for col in cat_cols:
    print(col)
# Out:
# Genes in mother's side
# Inherited from father
# Maternal gene
# Paternal gene
# Patient First Name
# Father's name
# Location of Institute
# Status
# Respiratory Rate (breaths/min)
# Heart Rate (rates/min
# Parental consent
# Follow-up
# Gender
# Birth asphyxia
# Autopsy shows birth defect (if applicable)
# Place of birth
# Folic acid details (peri-conceptional)
# H/O serious maternal illness
# H/O radiation exposure (x-ray)
# H/O substance abuse
# Assisted conception IVF/ART
# History of anomalies in previous pregnancies
# Birth defects
# Blood test result
# Genetic Disorder
# Disorder Subclass

# %%
train.drop(columns=["Disorder Subclass"], inplace=True, errors="ignore")
test.drop(columns=["Disorder Subclass"], inplace=True, errors="ignore")

# %%
cat_cols = train.select_dtypes(include="str").columns

# %%
print(cat_cols)
# Out:
# Index(['Genes in mother's side', 'Inherited from father', 'Maternal gene',
#        'Paternal gene', 'Patient First Name', 'Father's name',
#        'Location of Institute', 'Status', 'Respiratory Rate (breaths/min)',
#        'Heart Rate (rates/min', 'Parental consent', 'Follow-up', 'Gender',
#        'Birth asphyxia', 'Autopsy shows birth defect (if applicable)',
#        'Place of birth', 'Folic acid details (peri-conceptional)',
#        'H/O serious maternal illness', 'H/O radiation exposure (x-ray)',
#        'H/O substance abuse', 'Assisted conception IVF/ART',
#        'History of anomalies in previous pregnancies', 'Birth defects',
#        'Blood test result', 'Genetic Disorder'],
#       dtype='str')

# %%
cat_cols = train.select_dtypes(include="object").columns.tolist()
# Out:
# /tmp/ipykernel_47839/1716790888.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols = train.select_dtypes(include="object").columns.tolist()

# %%
cat_cols.remove("Genetic Disorder")

# %%
if "Disorder Subclass" in cat_cols:
    cat_cols.remove("Disorder Subclass")

# %%
print(cat_cols)
# Out:
# ["Genes in mother's side", 'Inherited from father', 'Maternal gene', 'Paternal gene', 'Patient First Name', "Father's name", 'Location of Institute', 'Status', 'Respiratory Rate (breaths/min)', 'Heart Rate (rates/min', 'Parental consent', 'Follow-up', 'Gender', 'Birth asphyxia', 'Autopsy shows birth defect (if applicable)', 'Place of birth', 'Folic acid details (peri-conceptional)', 'H/O serious maternal illness', 'H/O radiation exposure (x-ray)', 'H/O substance abuse', 'Assisted conception IVF/ART', 'History of anomalies in previous pregnancies', 'Birth defects', 'Blood test result']

# %%
for col in cat_cols:
    train[col] = train[col].fillna(train[col].mode()[0])
    test[col] = test[col].fillna(train[col].mode()[0])

# %%
train["Genetic Disorder"] = train["Genetic Disorder"].fillna(
    train["Genetic Disorder"].mode()[0]
)

# %%
train.isnull().sum()
# Out:
# Patient Age                                         0
# Genes in mother's side                              0
# Inherited from father                               0
# Maternal gene                                       0
# Paternal gene                                       0
# Blood cell count (mcL)                              0
# Patient First Name                                  0
# Father's name                                       0
# Mother's age                                        0
# Father's age                                        0
# Location of Institute                               0
# Status                                              0
# Respiratory Rate (breaths/min)                      0
# Heart Rate (rates/min                               0
# Test 1                                              0
# Test 2                                              0
# Test 3                                              0
# Test 4                                              0
# Test 5                                              0
# Parental consent                                    0
# Follow-up                                           0
# Gender                                              0
# Birth asphyxia                                      0
# Autopsy shows birth defect (if applicable)          0
# Place of birth                                      0
# Folic acid details (peri-conceptional)              0
# H/O serious maternal illness                        0
# H/O radiation exposure (x-ray)                      0
# H/O substance abuse                                 0
# Assisted conception IVF/ART                         0
# History of anomalies in previous pregnancies        0
# No. of previous abortion                            0
# Birth defects                                       0
# White Blood cell count (thousand per microliter)    0
# Blood test result                                   0
# Symptom 1                                           0
# Symptom 2                                           0
# Symptom 3                                           0
# Symptom 4                                           0
# Symptom 5                                           0
# Genetic Disorder                                    0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Patient Age                                         0
# Genes in mother's side                              0
# Inherited from father                               0
# Maternal gene                                       0
# Paternal gene                                       0
# Blood cell count (mcL)                              0
# Patient First Name                                  0
# Father's name                                       0
# Mother's age                                        0
# Father's age                                        0
# Location of Institute                               0
# Status                                              0
# Respiratory Rate (breaths/min)                      0
# Heart Rate (rates/min                               0
# Test 1                                              0
# Test 2                                              0
# Test 3                                              0
# Test 4                                              0
# Test 5                                              0
# Parental consent                                    0
# Follow-up                                           0
# Gender                                              0
# Birth asphyxia                                      0
# Autopsy shows birth defect (if applicable)          0
# Place of birth                                      0
# Folic acid details (peri-conceptional)              0
# H/O serious maternal illness                        0
# H/O radiation exposure (x-ray)                      0
# H/O substance abuse                                 0
# Assisted conception IVF/ART                         0
# History of anomalies in previous pregnancies        0
# No. of previous abortion                            0
# Birth defects                                       0
# White Blood cell count (thousand per microliter)    0
# Blood test result                                   0
# Symptom 1                                           0
# Symptom 2                                           0
# Symptom 3                                           0
# Symptom 4                                           0
# Symptom 5                                           0
# dtype: int64

# %%
train.to_csv("train_cleaned.csv", index=False)
test.to_csv("test_cleaned.csv", index=False)
